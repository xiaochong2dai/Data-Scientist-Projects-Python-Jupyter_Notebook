# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! ls
# Out:
# a.csv                    kaggle-titanic.ipynb     week1-raw.ipynb
# demo_1.py                pivot_table.csv          week1.ipynb
# df2.csv                  result.csv               week1.pptx
# homework.txt             test.csv                 week1.pptx 2.zip
# housing.data.txt         train.csv                week1.pptx.zip
# kaggle-titanic-raw.ipynb trash

# %%
! head train.csv
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/5 21171,7.25,,S
# 2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)",female,38,1,0,PC 17599,71.2833,C85,C
# 3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,STON/O2. 3101282,7.925,,S
# 4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May Peel)",female,35,1,0,113803,53.1,C123,S
# 5,0,3,"Allen, Mr. William Henry",male,35,0,0,373450,8.05,,S
# 6,0,3,"Moran, Mr. James",male,,0,0,330877,8.4583,,Q
# 7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17463,51.8625,E46,S
# 8,0,3,"Palsson, Master. Gosta Leonard",male,2,3,1,349909,21.075,,S
# 9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)",female,27,0,2,347742,11.1333,,S

# %%
! tail train.csv
# Out:
# 882,0,3,"Markun, Mr. Johann",male,33,0,0,349257,7.8958,,S
# 883,0,3,"Dahlberg, Miss. Gerda Ulrika",female,22,0,0,7552,10.5167,,S
# 884,0,2,"Banfield, Mr. Frederick James",male,28,0,0,C.A./SOTON 34068,10.5,,S
# 885,0,3,"Sutehall, Mr. Henry Jr",male,25,0,0,SOTON/OQ 392076,7.05,,S
# 886,0,3,"Rice, Mrs. William (Margaret Norton)",female,39,0,5,382652,29.125,,Q
# 887,0,2,"Montvila, Rev. Juozas",male,27,0,0,211536,13,,S
# 888,1,1,"Graham, Miss. Margaret Edith",female,19,0,0,112053,30,B42,S
# 889,0,3,"Johnston, Miss. Catherine Helen ""Carrie""",female,,1,2,W./C. 6607,23.45,,S
# 890,1,1,"Behr, Mr. Karl Howell",male,26,0,0,111369,30,C148,C
# 891,0,3,"Dooley, Mr. Patrick",male,32,0,0,370376,7.75,,Q

# %%
df = pd.read_csv('train.csv')

# %%
# Step 1. explore the data (head, tail, describe, include, dtypes)
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# step 2. let's make the data set cleaner (drop, dropna), remove Cabin
df.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df1 = df.drop('Cabin', axis=1)
print df.shape, df1.shape
# Out:
# (891, 12) (891, 11)

# %%
df1.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df2 = df1.dropna()

# %%
df2 = df1.dropna().copy()

# %%
print df.shape, df1.shape, df2.shape
# Out:
# (891, 12) (891, 11) (712, 11)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df2['Pclass'][0] = 1000
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# step 3. row & column selection ([], :, .ix, Boolean Series, Complicated Boolean, idxmin, idxmax)
# df2[['Survived', 'Sex']]
# df2.ix[3:5]
# df2.ix[3:10, ['Survived', 'Name']]
#one = (df2.Survived == 1)
#df2.ix[one, ['Name', 'Sex']]
# df2.ix[(df2.Survived == 1), ['Name', 'Sex']]
# df2.head(2)

# %%
df2.ix[(df2.Survived == 1), ['Survived', 'Name']]
# Out:
#      Survived                                               Name
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1                             Heikkinen, Miss. Laina
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1                    Sandstrom, Miss. Marguerite Rut
# 11          1                           Bonnell, Miss. Elizabeth
# 15          1                   Hewlett, Mrs. (Mary D Kingcome)
# 21          1                              Beesley, Mr. Lawrence
# 22          1                        McGowan, Miss. Anna "Annie"
# 23          1                       Sloper, Mr. William Thompson
# 25          1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 39          1                        Nicola-Yarred, Miss. Jamila
# ...

# %%
df2['Age2'] = df2['Age'] * 2

# %%
# Step 4. Flexible data operation (+/-, **, comparison(>=<), Boolean with all/any)
#                                 (Age a+a == a*2)
# df2.ix[:,'Age2'] = df2.ix[:,'Age'] * 2

# %%
# Step 5. Descriptive statistics (mean, max, sum, std, skew, kurt, quantile, median, abs, or np style if like)
# df2.Age.quantile(0.3)

# %%
df2.describe()
# Out:
#        PassengerId    Survived       Pclass         Age       SibSp  \
# count   712.000000  712.000000   712.000000  712.000000  712.000000
# mean    448.589888    0.404494     3.640449   29.642093    0.514045
# std     258.683191    0.491139    37.402023   14.492933    0.930692
# min       1.000000    0.000000     1.000000    0.420000    0.000000
# 25%     222.750000    0.000000     1.000000   20.000000    0.000000
# 50%     445.000000    0.000000     2.000000   28.000000    0.000000
# 75%     677.250000    1.000000     3.000000   38.000000    1.000000
# max     891.000000    1.000000  1000.000000   80.000000    5.000000
#
#             Parch        Fare
# count  712.000000  712.000000
# mean     0.432584   34.567251
# std      0.854181   52.938648
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.645850
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %%
df2[['Survived', 'Age']].abs().mean()
# Out:
# Survived     0.404494
# Age         29.642093
# dtype: float64

# %%
df2.Age.quantile(0.5)
# Out:
# 28.0

# %%
df2['Age'].quantile(0.5)
# Out:
# 28.0

# %%
df2.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Embarked'],
#       dtype='object')

# %%
# df2.columns
pd.qcut?

# %%
# Step 6. Categorical variables (value_counts, pd style vs self-style; qcut + value_counts)
# df2['Pclass'].value_counts()
the_cut = pd.qcut(df2.Age, [0, 0.2, 0.4, 0.6, 0.8, 1])
print type(the_cut), the_cut[0:10]
the_cut.value_counts()
# Out:
# <class 'pandas.core.series.Series'> 0       (19, 25]
# 1       (31, 41]
# 2       (25, 31]
# 3       (31, 41]
# 4       (31, 41]
# 6       (41, 80]
# 7     [0.42, 19]
# 8       (25, 31]
# 9     [0.42, 19]
# 10    [0.42, 19]
# Name: Age, dtype: category
# Categories (5, object): [[0.42, 19] < (19, 25] < (25, 31] < (31, 41] < (41, 80]]
# [0.42, 19]    164
# (31, 41]      143
# (41, 80]      141
# (19, 25]      137
# (25, 31]      127
# Name: Age, dtype: int64

# %%
the_cut.unique()
# Out:
# [(19, 25], (31, 41], (25, 31], (41, 80], [0.42, 19]]
# Categories (5, object): [[0.42, 19] < (19, 25] < (25, 31] < (31, 41] < (41, 80]]

# %%
the_cut.value_counts()
# Out:
# [0.42, 19]    164
# (31, 41]      143
# (41, 80]      141
# (19, 25]      137
# (25, 31]      127
# Name: Age, dtype: int64

# %%
df2.Sex.value_counts(normalize=True)
# Out:
# male      0.636236
# female    0.363764
# Name: Sex, dtype: float64

# %%
# Step 7. more complicated transformation (apply, applymap) get last name out of the Name

# %%
df2['new_variable'] = df2.apply(lambda x: x.Age + x.Fare, axis=1)

# %%
df2['new_variable_1'] = df2.apply(lambda x: x.Sex + x.Name, axis=1)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  new_variable  \
# 0      0         A/5 21171   7.2500        S       29.2500
# 1      0          PC 17599  71.2833        C      109.2833
# 2      0  STON/O2. 3101282   7.9250        S       33.9250
# 3      0            113803  53.1000        S       88.1000
# ...

# %%
df3 = df2.query("Age > 20 & Sex == 'male'")
print df2.shape, df3.shape
# Out:
# (712, 13) (351, 13)

# %%
df3 = df2[(df2.Age > 20) & (df2.Sex == 'male')]
print df2.shape, df3.shape
# Out:
# (712, 13) (351, 13)

# %%
# Step 8. change column names (rename, or columns assignment) SibSp to has_sibling

# %%
df2 = df2.rename(columns={'Age2': 'Age_new'})

# %%
df2.sort_values(['Age', 'Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 78            79         1       2
# 831          832         1       2
# 305          306         1       1
# 172          173         1       3
# 381          382         1       3
# 164          165         0       3
# 183          184         1       2
# 386          387         0       3
# 788          789         1       3
# 827          828         1       2
# 119          120         0       3
# 205          206         0       3
# 297          298         0       1
# 479          480         1       3
# 530          531         1       2
# 642          643         0       3
# 7              8         0       3
# 16            17         0       3
# 340          341         1       2
# 824          825         0       3
# 43            44         1       2
# ...

# %%
# Step 9. sort (by value, by index, ascending
df1 = df.sort_values(by=['Sex', 'Age'], ascending=[True, False])
df2 = df1.sort_index(ascending=False)

# %%
df2.sort_values(by=['Age'], ascending=[False])['Name'].head()
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# 851                     Svensson, Mr. Johan
# 493                 Artagaveytia, Mr. Ramon
# 96                Goldschmidt, Mr. George B
# 116                    Connors, Mr. Patrick
# Name: Name, dtype: object

# %%
# Step 10. iteration (iterrows, itertuples)

# %%
for key, value in df2.iterrows():
    print key
    print value
    # XXXXXX
    break
# Out:
# 0
# PassengerId                                 1
# Survived                                    0
# Pclass                                      3
# Name                  Braund, Mr. Owen Harris
# Sex                                      male
# Age                                        22
# SibSp                                       1
# Parch                                       0
# Ticket                              A/5 21171
# Fare                                     7.25
# Embarked                                    S
# new_variable                            29.25
# new_variable_1    maleBraund, Mr. Owen Harris
# Name: 0, dtype: object

# %%
# Step 11. GroupBy & agg

# %%
df2.groupby('Sex').mean()['Survived']
# Out:
# Sex
# female    0.752896
# male      0.205298
# Name: Survived, dtype: float64

# %%
result = df2.groupby('Sex').agg({'Survived': ['mean', 'sum']})

# %%
result
# Out:
#         Survived
#             mean  sum
# Sex
# female  0.752896  195
# male    0.205298   93

# %%
# Step 12. Merge, Join, Concat (create two tables, name, price, class)

# %%
pd.merge()

# %%
# Step 13. pivot table
# a = pd.pivot_table(df, columns=['Survived'], index=['Sex'], values='Fare', aggfunc=np.sum)

# %%
a = pd.pivot_table(df, columns=['Survived'], index=['Sex'], values='Fare', aggfunc=np.mean)

# %%
a
# Out:
# Survived          0          1
# Sex
# female    23.024385  51.938573
# male      21.960993  40.821484

# %%
# Step 14. output data

# %%
result.to_csv('result.csv')
